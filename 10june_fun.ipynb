# %%
"""1. In Python, what is the difference between a built-in function and a user-defined function? Provide an
example of each.
Ans:
difference between a built-in function and a user-defined function is their origin and availability.

Built-in Function:

i.Built-in functions are pre-defined functions that are provided by the Python programming language.
ii.These functions are readily available for use without requiring any additional code or import statements.
iii.Examples of built-in functions include print(), len(), max(), min(), and sum().
 Example of a built-in function
text = "Hello, World!"
print(len(text))  

Output: 13


User-defined Function:

i.User-defined functions are created by the users or developers as per their specific requirements.
ii.These functions are defined using the def keyword followed by a function name, optional parameters, and a block of code.
iii.User-defined functions provide a way to modularize code and make it reusable.
Examples of user-defined functions include functions created by the developer to perform custom tasks or operations.
 Example of a user-defined function
def multiply(a, b):
    return a * b

result = multiply(5, 3)
print(result) 

Output: 15


"""
# Out:
# '1. In Python, what is the difference between a built-in function and a user-defined function? Provide an\nexample of each.\nAns:\ndifference between a built-in function and a user-defined function is their origin and availability.\n\nBuilt-in Function:\n\ni.Built-in functions are pre-defined functions that are provided by the Python programming language.\nii.These functions are readily available for use without requiring any additional code or import statements.\niii.Examples of built-in functions include print(), len(), max(), min(), and sum().\n Example of a built-in function\ntext = "Hello, World!"\nprint(len(text))  \n\nOutput: 13\n\n\nUser-defined Function:\n\ni.User-defined functions are created by the users or developers as per their specific requirements.\nii.These functions are defined using the def keyword followed by a function name, optional parameters, and a block of code.\niii.User-defined functions provide a way to modularize code and make it reusable.\nExamples of us
# ...

# %%
"""
2. How can you pass arguments to a function in Python? Explain the difference between positional
arguments and keyword arguments.

Ans:
These are the different ways to pass arguments to a function in Python. You can choose the appropriate method based on your specific requirements and the nature of
the arguments you need to pass.
i.Positional Arguments:Positional arguments are commonly used when the order of the arguments is important.
def add(a, b):
    return a + b

result = add(3, 5)
print(result)  # Output: 8

ii.Keyword Arguments:Keyword arguments are useful when you want to explicitly specify which argument corresponds to which parameter, especially in functions with 
multiple parameters.
def greet(name, age):
    print(f"Hello, {name}! You are {age} years old.")

greet(age=30, name="Alice")
# Output: Hello, Alice! You are 30 years old.


iii.Default Arguments:Default arguments are parameters that have a default value assigned in the function definition.
def greet(name, age=18):
    print(f"Hello, {name}! You are {age} years old.")

greet("Bob")
# Output: Hello, Bob! You are 18 years old.


iv.Variable Length Arguments:Python allows you to define functions that can accept a variable number of arguments.
These arguments are collected into a tuple args and a dictionary kwargs, respectively, within the function.
def multiply(*args):
    result = 1
    for num in args:
        result *= num
    return result

result = multiply(2, 3, 4)
print(result)  # Output: 24


 Explain the difference between positional arguments and keyword arguments.

Positional Arguments:

i.Positional arguments are passed to a function based on their position or order.
ii.The values are assigned to function parameters in the order they are passed.
iii.The number of arguments passed must match the number of parameters defined in the function.
iv.Positional arguments are commonly used when the order of the arguments is important.
def add(a, b):
    return a + b

result = add(3, 5)
print(result)  # Output: 8


Keyword Arguments:

i.Keyword arguments are passed to a function using the name of the parameter.
ii.The arguments are assigned to the function parameters based on their names, allowing flexibility in the order.
iii.Keyword arguments are useful when you want to explicitly specify which argument corresponds to which parameter, especially in functions with multiple parameters.
def greet(name, age):
    print(f"Hello, {name}! You are {age} years old.")

greet(age=30, name="Alice")
# Output: Hello, Alice! You are 30 years old.

"""

# %%
"""
3. What is the purpose of the return statement in a function? Can a function have multiple return
statements? Explain with an example.

Ans:
The return statement in a function is used to specify the value that the function should return when it is called. It serves two main purposes:

To Provide Output:

i.The return statement allows a function to provide a result or output to the caller.
ii.It specifies the value that will be passed back to the caller of the function.
iii.The returned value can be used for further computations, assignments, or any desired operations.
To Terminate the Function Execution:

i.The return statement also acts as a termination point for the function.
ii.When a return statement is encountered, the function immediately exits, and the control flow is returned to the caller.
iii.A function can have multiple return statements. Once a return statement is executed, the function terminates and returns the specified value. In the case of multiple return statements, only one return statement is executed during the function's execution.
def get_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    else:
        return "D"

student1_score = 85
student1_grade = get_grade(student1_score)
print(student1_grade)  # Output: "B"

student2_score = 92
student2_grade = get_grade(student2_score)
print(student2_grade)  # Output: "A"


"""

# %%
"""
4. What are lambda functions in Python? How are they different from regular functions? Provide an
example where a lambda function can be useful.
Ans:
Lambda functions, also known as anonymous functions, are small, one-line functions in Python that can be defined without a name. They are created using the lambda keyword
and are typically used for simple, short tasks.

Lambda functions are different from regular functions in terms of their syntax and usage. The main differences are:

i.Function Name: Lambda functions don't have a name and are not bound to any identifier, while regular functions are defined with a name and can be called using that name.

ii.Function Definition: Lambda functions are defined using the lambda keyword, while regular functions are defined using the def keyword.

iii.Function Body: Lambda functions have a single expression as their body, while regular functions can have multiple statements and more complex logic.

iv.Scope: Lambda functions are typically used for small and immediate tasks, often as arguments to higher-order functions like map(), filter(), or reduce(). Regular functions are more versatile and can be used in various contexts.
# Using lambda function to sort a list of tuples based on the second element
students = [("Alice", 80), ("Bob", 90), ("Charlie", 75), ("David", 95)]
sorted_students = sorted(students, key=lambda x: x[1])
print(sorted_students)
# Output: [('Charlie', 75), ('Alice', 80), ('Bob', 90), ('David', 95)]

"""

# %%
"""
5. How does the concept of "scope" apply to functions in Python? Explain the difference between local
scope and global scope.
Ans:
scope refers to the region or context in which variables, objects, and names are defined and can be accessed. It determines the visibility and accessibility of variables within a program. When it comes to functions in Python, there are two main scopes to consider: local scope and global scope.

Local Scope:

i.Local scope refers to the region within a function where variables are defined and can be accessed.
ii.Variables defined within a function are considered local to that function and can only be accessed from within the function.
iii.Local variables have a limited lifespan and are created when the function is called, and they cease to exist when the function completes execution or returns.
iv.Local variables can have the same name as variables in other scopes without causing conflicts because they are independent and separate from variables in other scopes.
def my_function():
    x = 10  # Local variable
    print(x)

my_function()  # Output: 10
print(x)  # Error: NameError: name 'x' is not defined (x is not accessible outside the function)

Global Scope:

i.Global scope refers to the outermost level of the program, outside of any function or class.
ii.Variables defined outside of all functions or classes are considered global and can be accessed from anywhere within the program, including inside functions.
iii.Global variables have a broader scope and a longer lifespan compared to local variables.
iv.Global variables can be accessed, modified, or referenced by any part of the program.
x = 10  # Global variable

def my_function():
    print(x)  # Accessing global variable

my_function()  # Output: 10
print(x)  # Output: 10

"""

# %%
"""
6. How can you use the "return" statement in a Python function to return multiple values?
Ans.

In Python, the return statement can be used to return multiple values from a function by returning them as a single data structure. There are a few approaches to achieve this:
i.Return as a Tuple:

You can use a tuple to group multiple values and return them as a single tuple.
The values can be enclosed in parentheses or simply separated by commas.
def get_values():
    value1 = 10
    value2 = "Hello"
    return value1, value2

result = get_values()
print(result)  # Output: (10, 'Hello')

ii.Return as a List:

Similar to using a tuple, you can use a list to group multiple values and return them as a single list.
def get_values():
    value1 = 10
    value2 = "Hello"
    return [value1, value2]

result = get_values()
print(result)  # Output: [10, 'Hello']

iii.Return as a Dictionary:

You can also use a dictionary to return multiple values, where each value is associated with a specific key.
def get_values():
    value1 = 10
    value2 = "Hello"
    return {'val1': value1, 'val2': value2}

result = get_values()
print(result)  # Output: {'val1': 10, 'val2': 'Hello'}


"""

# %%
""""
7. What is the difference between the "pass by value" and "pass by reference" concepts when it
comes to function arguments in Python?
Ans:
Pass by Value:

i.In a language that implements "pass by value," a copy of the value of a variable is passed to a function.
ii.Any changes made to the parameter inside the function do not affect the original variable.


Pass by Reference:

i.In a language that implements "pass by reference," a reference or memory address of a variable is passed to a function.
ii.Any changes made to the parameter inside the function affect the original variable.

In Python, the behavior is different:

Python uses "pass by object reference" or "call by object reference."
When a variable is passed as an argument to a function, the reference to the object is passed, not the value itself.
The parameter inside the function becomes a new reference to the same object in memory.
Changes made to the parameter inside the function can affect the original object.
"""

# %%
"""
8. Create a function that can intake integer or decimal value and do following operations:
a. Logarithmic function (log x)
b. Exponential function (exp(x))
c. Power function with base 2 (2x)
d. Square root

Ans:
import math

def perform_operations(x):
    # Logarithmic function (log x)
    logarithm = math.log(x)
    
    # Exponential function (exp(x))
    exponential = math.exp(x)
    
    # Power function with base 2 (2^x)
    power = 2 ** x
    
    # Square root
    square_root = math.sqrt(x)
    
    # Print the results
    print("Logarithm:", logarithm)
    print("Exponential:", exponential)
    print("Power (Base 2):", power)
    print("Square Root:", square_root)

# Test the function
value = 3.5
perform_operations(value)


"""

# %%
"""
9. Create a function that takes a full name as an argument and returns first name and last name.
Ans:

"""
# Out:
# '\n9. Create a function that takes a full name as an argument and returns first name and last name.\nAns:\n\n'

# %%
def extract_names(full_name):
    # Split the full name into a list of words
    name_parts = full_name.split()

    # Extract the first name (first word)
    first_name = name_parts[0]

    # Extract the last name (last word)
    last_name = name_parts[-1]

    # Return the first name and last name as a tuple
    return first_name, last_name

# Test the function
name = "John Doe"
first, last = extract_names(name)
print("First Name:", first)
print("Last Name:", last)
# Out:
# First Name: John
# Last Name: Doe
